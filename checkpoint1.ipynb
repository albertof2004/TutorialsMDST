# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pn.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_EST'},
    axis=1,inplace=True)
df.dropna(subset=['AVG_MATH_8_SCORE'], inplace=True)
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL_ALL_EST  TOTAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992             NaN      2678885.0
# 2     1992_ARIZONA     ARIZONA  1992             NaN      3258079.0
# 3    1992_ARKANSAS    ARKANSAS  1992             NaN      1711959.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992             NaN     26260025.0
# 5    1992_COLORADO    COLORADO  1992             NaN      3185173.0
#
#    FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 0         304177.0      1659028.0       715680.0          2653798.0
# 2         297888.0      1369815.0      1590376.0          3401580.0
# 3         178571.0       958785.0       574603.0          1743022.0
# 4        2072470.0     16546514.0      7641041.0         27138832.0
# 5         163253.0      1307986.0      1713934.0          3264826.0
#
#    INSTRUCTION_EXPENDITURE  ...  ENROLL_4  ENROLL_8  ENROLL_12  \
# 0                1481703.0  ...   57948.0   58025.0    41167.0
# ...

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen one of Grade 4 Reading, Grade 4 Math, or Grade 8 Math to focus on: *Grade 8 Math*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
num_years = df["YEAR"].nunique()
print("Number of years logged in the dataset:", num_years)
# Out:
# Number of years logged in the dataset: 13

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average across all years in the test you chose?

# %%
def highest_avg(df):
    michigan_score = df.loc[df['STATE'] == "MICHIGAN", 'AVG_MATH_8_SCORE'].mean()
    ohio_score = df.loc[df['STATE'] == "OHIO", 'AVG_MATH_8_SCORE'].mean()
    if michigan_score > ohio_score:
        return "Michigan"
    else:
        return "Ohio"
print (highest_avg(df))
# Out:
# Ohio

# %% [markdown]
# Find the average for your chosen test across all states in 2019

# %%
average_test_2019 = df.loc[df['YEAR']== 2019,'AVG_MATH_8_SCORE'].mean()
print("Average math score for 8th graders across all states in 2019:", average_test_2019)
# Out:
# Average math score for 8th graders across all states in 2019: 281.2641509433962

# %% [markdown]
# For each state, find a maximum value for your chosen test score
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
max_value_state = df.groupby('STATE')['AVG_MATH_8_SCORE'].max()
print (max_value_state)
# Out:
# STATE
# ALABAMA                 269.0
# ALASKA                  283.0
# ARIZONA                 283.0
# ARKANSAS                279.0
# CALIFORNIA              277.0
# COLORADO                292.0
# CONNECTICUT             289.0
# DELAWARE                284.0
# DISTRICT_OF_COLUMBIA    269.0
# DODEA                   293.0
# FLORIDA                 281.0
# GEORGIA                 281.0
# HAWAII                  281.0
# IDAHO                   287.0
# ILLINOIS                285.0
# INDIANA                 288.0
# IOWA                    286.0
# KANSAS                  290.0
# KENTUCKY                282.0
# LOUISIANA               273.0
# MAINE                   289.0
# MARYLAND                288.0
# MASSACHUSETTS           301.0
# MICHIGAN                280.0
# MINNESOTA               295.0
# MISSISSIPPI             274.0
# MISSOURI                286.0
# MONTANA                 293.0
# NATIONAL                285.0
# NEBRASKA                288.0
# NEVADA                  278.0
# ...

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
df['TOTAL_EXPENDITURE_PER_STUDENT'] = df['TOTAL_EXPENDITURE'] / df['ENROLL_ALL']

df['TOTAL_INSTRUCTIONAL_EXPENDITURE_PER_STUDENT'] = df['INSTRUCTION_EXPENDITURE'] / df['ENROLL_ALL']

bins = [0, 1000000, 5000000, 10000000, 50000000, np.inf]
labels = ['Low', 'Medium', 'High', 'Very High', 'Ultra High']
df['TOTAL_REVENUE_BIN'] = pd.cut(df['TOTAL_REVENUE'], bins=bins, labels=labels)

# %% [markdown]
# Feature engineering justification:
# 1) and 2): As mentioned in the tutorial, states have different amounts of people. Analyzing the total expenditure and the total instructional expenditure per student could give us more precise insights.
# 3):Binning reduces the significance of small differences in data and objectively groups total revenue into broader categories

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
filtered_df = df[(df['YEAR'] >= 2019) & (df['YEAR'] <= 2021)]
filtered_df['AVG_MATH_8_SCORE'].plot.hist(title="Distribution of 8th Grade Math Scores (2019-2021)", bins = 10, edgecolor="black")
# Out:
# <AxesSubplot:title={'center':'Distribution of 8th Grade Math Scores (2019-2021)'}, ylabel='Frequency'>

# %% [markdown]
# This graph illustrates the distribution of frequencies of average math scores between the years 2019 and 2021. The highest score obtained in the 8th Grade Math Scores is approximately 285, while the lowest scores are around 272, 277, and 290. Additionally, the graph reveals that the scores are concentrated between approximately 270 and 295, and within this range, they do not exhibit a rigid trend.

# %% [markdown]
# **Visualization 2**

# %%
import matplotlib.pyplot as plt

average_math_scores = df.groupby('YEAR')['AVG_MATH_8_SCORE'].mean()

average_math_scores.plot()
plt.ylabel('Average Math Score') 
plt.title('Trend of 8th Grade Math Scores Over Time')  

plt.show()

# %% [markdown]
# The graph depicts the evolution of the average 8th-grade math score over the years. Notably, from 1990 to 2012, there was a significant increase, soaring from approximately 262 to 283 within a span of 22 years. However, between 2012 and 2018, a modest decline occurred, with the average score receding from 283 to 281. This visualization provides insight into the trends and fluctuations in 8th-grade math performance over the depicted timeframe

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['AVG_READING_8_SCORE', 'AVG_READING_4_SCORE', 'AVG_MATH_4_SCORE']].dropna()
y = df.loc[X.index]['AVG_MATH_8_SCORE']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
print("model intercept:", model.intercept_)
print("model coef:", model.coef_)

prediction_errors = model.predict(X_test) - y_test
mean_prediction_error = np.mean(prediction_errors)
print("mean prediction error:", mean_prediction_error)

accuracy = model.score(X_test, y_test)
print("model accuracy:", accuracy)
# Out:
# model intercept: -38.839300671070475
# model coef: [ 0.70454269 -0.32383969  0.85858469]
# mean prediction error: -0.5504062488500436
# model accuracy: 0.9117772233706798

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_READING_8_SCORE'

f = plt.figure(figsize=(12, 6))
plt.scatter(X_train[col_name], y_train, color="red", label='True Training')
plt.scatter(X_train[col_name], model.predict(X_train), color="green", label='Predicted Training')

plt.legend()
plt.xlabel(col_name)
plt.ylabel('Math 8 score')
plt.title("Model Behavior On Training Set")
plt.show()

# %%
col_name = 'AVG_READING_8_SCORE'

f = plt.figure(figsize=(12, 6))
plt.scatter(X_test[col_name], y_test, color="blue", label='True testing')
plt.scatter(X_test[col_name], model.predict(X_test), color="black", label='Predicted testing')

plt.legend()
plt.xlabel(col_name)
plt.ylabel('Math 8 score')
plt.title("Model Behavior on Testing Set")
plt.show()

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# Starting with the initial results from our linear regression model, we found that the model intercept was approximately -38.839. The coefficients associated with the predictors indicated a relationship between the predictors and the target variable 'Math 8 score'. Specifically, for 'AVG_READING_8_SCORE', the coefficient was approximately 0.705. For 'AVG_READING_4_SCORE', it was approximately -0.324, and for 'AVG_MATH_4_SCORE', it was approximately 0.859. Despite these coefficients suggesting a relationship, the mean prediction error was approximately -0.55, indicating some deviation in the model's predictions from the actual values. However, with a model accuracy of approximately 91.18%, it's evident that the model captures a substantial portion of the variation in the data.
#
# The graphs plotted illustrate the model's behavior on both the training and testing sets. In the training set visualization, the true training values ('True Training') and the predicted training values ('Predicted Training') show alignment, affirming the model's performance. Similarly, in the testing set visualization, the true testing values ('True testing') and the predicted testing values ('Predicted testing') exhibit closeness, further validating the model's accuracy and effectiveness in predicting 'Math 8 score' based on 'AVG_READING_8_SCORE'.
